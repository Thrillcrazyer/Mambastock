# %%
import os
os.chdir('/workspace')
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import torch
from dataset.dataset_iter import data_formatting
warnings.filterwarnings('ignore')
from tqdm import tqdm

device="cuda"
d_type=torch.float32

# %%
import os

# 현재 위치
os.getcwd()
# Out:
# '/workspace'

# %% [markdown]
# # Modeling

# %%
def Mamba2Model():
    from model.mamba_stock import Mambamodeling
    pretrained_path="/workspace/weight/Mamba2Single"
    model=Mambamodeling(
            d_model=768,
            d_inermediate=2048,
            n_layer=8,
            layer="Mamba2",
            pad_vocab_size_multiple=1,
            stock_feature=1,
            pretrained_path=pretrained_path
        ).to(device)
    model.eval()
    return model


def Mamba1Model():
    from model.mamba_stock import Mambamodeling
    pretrained_path="/workspace/weight/Mamba1Single"
    model=Mambamodeling(
            d_model=768,
            d_inermediate=2048,
            n_layer=8,
            layer="Mamba1",
            pad_vocab_size_multiple=1,
            stock_feature=1,
            pretrained_path=pretrained_path
        ).to(device)
    model.eval()
    return model

def TransformerModel():
    from model.qwen_stock import QwenStock
    from transformers import AutoConfig
    
    model_name = "Qwen/Qwen2.5-Coder-0.5B-Instruct"
    
    qwenconfig=AutoConfig.from_pretrained(model_name,
                    intermediate_size= 2048,
                    max_position_embeddings= 128,
                    num_hidden_layers=8,
                    vocab_size= 1
                    )

    model=QwenStock(qwenconfig).from_pretrained("/workspace/weight/QWENSingle").to(device)
    return model

def predict(data,model,seq_length):
    stock_predictions=[]
    total= len(data)-seq_length
    
    for start_idx in tqdm(range(total), desc="Prediction", ncols=80, ascii=True):
        open=data.loc[data.index[start_idx], "Open"]
        input=data_formatting(data,start_idx,1,seq_length,d_type,is_multi=False)
        with torch.no_grad():
            pred=model(input)[0,-1,:]
        price_pred=pred*open/100
        stock_predictions.append(price_pred)
        if start_idx%200==0:
            torch.cuda.empty_cache()
    stock_predictions=torch.cat(stock_predictions).cpu().numpy()
    data["predict"]=np.concatenate((np.zeros(seq_length), stock_predictions))
    return data

# %% [markdown]
# # Prediction

# %%
from backtesting.test import EURUSD,GOOG

data_path="/workspace/data/HBARUSDT_hour.csv"
stock=pd.read_csv(data_path)
#stock=EURUSD

#model=TransformerModel()
model=Mamba2Model()
predict(stock,model,127)
# Out:
# 1
# 1
# Mamba2 model is initialized.
# Total parameters: 67.88M
# Trainable parameters: 67.88M
# Prediction: 100%|#########################| 45783/45783 [09:20<00:00, 81.61it/s]
#        Unnamed: 0     open_time     Open     High      Low    Close  \
# 0               0  1.569730e+12  0.03103  0.04400  0.03103  0.03958
# 1               1  1.569733e+12  0.03953  0.03991  0.03905  0.03924
# 2               2  1.569737e+12  0.03922  0.03947  0.03755  0.03786
# 3               3  1.569740e+12  0.03790  0.03816  0.03690  0.03766
# 4               4  1.569744e+12  0.03785  0.03815  0.03662  0.03680
# ...           ...           ...      ...      ...      ...      ...
# 45905       45905  1.735117e+12  0.31031  0.32158  0.30974  0.32126
# 45906       45906  1.735121e+12  0.32126  0.32581  0.31293  0.31401
# 45907       45907  1.735124e+12  0.31400  0.31691  0.31112  0.31189
# 45908       45908  1.735128e+12  0.31190  0.31419  0.30984  0.31269
# 45909       45909  1.735132e+12  0.31268  0.31480  0.31151  0.31151
#
#            Volume  kline_close_time  quote_asset_volume  number_of_trades  \
# 0       5024848.8      1.569733e+12        2.018234e+05             856.0
# 1       2219095.5      1.569737e+12        8.757110e+04             338.0
# 2       1791939.6      1.569740e+12        6.899727e+04             331.0
# 3       1260399.9      1.569744e+12        4.719218e+04             244.0
# 4        697492.2      1.569748e+12        2.609966e+04             154.0
# ...           ...               ...                 ...               ...
# 45905  41188184.0      1.735121e+12        1.298938e+07           50931.0
# 45906  70810405.0      1.735124e+12        2.266288e+07          105419.0
# 45907  22296006.0      1.735128e+12        7.007405e+06           25234.0
# 45908  23856148.0      1.735132e+12        7.441434e+06           30832.0
# 45909   7052469.0      1.735135e+12        2.208275e+06            6650.0
#
#              base         quote        date   predict
# 0       2114335.8  8.505567e+04  2019-09-29  0.000000
# 1        698617.1  2.762996e+04  2019-09-29  0.000000
# 2        747785.5  2.881853e+04  2019-09-29  0.000000
# 3        543099.3  2.034389e+04  2019-09-29  0.000000
# 4        337175.1  1.263616e+04  2019-09-29  0.000000
# ...           ...           ...         ...       ...
# 45905  24008615.0  7.573562e+06  2024-12-25  0.296991
# 45906  36583004.0  1.172913e+07  2024-12-25  0.321285
# 45907   9703389.0  3.050373e+06  2024-12-25  0.313391
# 45908  11280025.0  3.520249e+06  2024-12-25  0.315915
# 45909   2552748.0  8.000851e+05  2024-12-25  0.317107
#
# [45910 rows x 14 columns]

# %%
# 데이터를 DataFrame으로 변환
#time= pd.to_datetime(stock['open_time'], unit='ms')
time=stock.index
# data2와 data1을 그래프로 그리기
plt.figure(figsize=(15, 10))  # 그래프 크기 설정 (선택적)
plt.plot(time, stock['Close'], label='real')
plt.plot(time, stock["predict"], label='predict')

# 그래프에 레이블과 범례 추가
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Real and Predict Over Time')
plt.legend()

# 그래프 표시
plt.show()

# %%
from backtesting import Strategy, Backtest
from backtesting.lib import SignalStrategy

class System(Strategy):
    def init(self):
        super().init()
        
    def next(self):
        price = self.data.Close[-1]
       
        
         
        if (self.data.predict - price)/price > 0.01 and (self.data.predict - price)/price<0.2 and self.data.predict != 0:
            if not self.position.is_long:
                self.position.close()
                self.buy()        
        else:
            self.position.close()
       
            
backtest = Backtest(stock, System,
              cash=10000,
              commission=0.0002,
              exclusive_orders=True)

output=backtest.run()
#output.to_csv("/workspace/result/Mamba2_S.csv")
output
# Out:
# Start                                     0.0
# End                                   45909.0
# Duration                              45909.0
# Exposure Time [%]                   31.692442
# Equity Final [$]                 66388.737538
# Equity Peak [$]                  78672.108908
# Return [%]                         563.887375
# Buy & Hold Return [%]              687.038909
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -59.654581
# Avg. Drawdown [%]                     -4.6893
# Max. Drawdown Duration                28310.0
# Avg. Drawdown Duration             323.207143
# # Trades                               6340.0
# Win Rate [%]                         52.85489
# Best Trade [%]                      38.239149
# Worst Trade [%]                    -16.369604
# Avg. Trade [%]                       0.029862
# Max. Trade Duration                       7.0
# Avg. Trade Duration                  1.294953
# Profit Factor                        1.089763
# Expectancy [%]                       0.043916
# SQN                                  0.968991
# _strategy                              System
# _equity_curve                          Equ...
# _trades                           Size  En...
# dtype: object

# %%
backtest.plot()
